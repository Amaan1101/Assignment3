# %%
#STEP 1: Import the necessary libraries
import pandas as pd

# %%
pwd()
# Out:
# 'C:\\Users\\Amaan'

# %%
#STEP 2: Import the dataset
#STEP 3: Assign it to variable called baby names

baby_names=pd.read_csv("US_Baby_Names_right.csv")

# %%
baby_names
# Out:
#          Unnamed: 0       Id     Name  Year Gender State  Count
# 0             11349    11350     Emma  2004      F    AK     62
# 1             11350    11351  Madison  2004      F    AK     48
# 2             11351    11352   Hannah  2004      F    AK     46
# 3             11352    11353    Grace  2004      F    AK     44
# 4             11353    11354    Emily  2004      F    AK     41
# ...             ...      ...      ...   ...    ...   ...    ...
# 1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 7 columns]

# %%
#STEP 4: See the first 10 entries
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %%
#STEP 5: Delete the column 'Unnamed: 0' and 'Id'
baby_names=pd.read_csv("US_Baby_Names_right.csv")

# %%
baby_names
# Out:
#          Unnamed: 0       Id     Name  Year Gender State  Count
# 0             11349    11350     Emma  2004      F    AK     62
# 1             11350    11351  Madison  2004      F    AK     48
# 2             11351    11352   Hannah  2004      F    AK     46
# 3             11352    11353    Grace  2004      F    AK     44
# 4             11353    11354    Emily  2004      F    AK     41
# ...             ...      ...      ...   ...    ...   ...    ...
# 1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 7 columns]

# %%
baby_names.drop(['Unnamed: 0','Id'], axis = 1)
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %%
#STEP 6: Is there more male or female names in the dataset?

baby_names["Gender"].value_counts()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %%
#STEP 7: Group the dataset by name and assign to names

Names= pd.read_csv("US_Baby_Names_right.csv")

# %%
Names
# Out:
#          Unnamed: 0       Id     Name  Year Gender State  Count
# 0             11349    11350     Emma  2004      F    AK     62
# 1             11350    11351  Madison  2004      F    AK     48
# 2             11351    11352   Hannah  2004      F    AK     46
# 3             11352    11353    Grace  2004      F    AK     44
# 4             11353    11354    Emily  2004      F    AK     41
# ...             ...      ...      ...   ...    ...   ...    ...
# 1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 7 columns]

# %%
Names.groupby('Name')
print(Names.groupby('Name').groups)
# Out:
# {'Aaban': [693699, 695768], 'Aadan': [120728, 123846, 138678, 897674], 'Aadarsh': [323950], 'Aaden': [17728, 18138, 18802, 19906, 20628, 21512, 22399, 33006, 33529, 34380, 55155, 55656, 56651, 57822, 60162, 62145, 116768, 119006, 121886, 125030, 128124, 131036, 134079, 136936, 153495, 154169, 154825, 155898, 156824, 159475, 168580, 169059, 169796, 181844, 216243, 218023, 220106, 222413, 223962, 225784, 227836, 253259, 254198, 255563, 257385, 258929, 260615, 261685, 263054, 268436, 280012, 280581, 281925, 320445, 321337, 322790, 324879, 326540, 328324, 329557, 331085, 348875, 349834, 351135, 352074, 365869, 366424, 367264, 381523, 382178, 383091, 383878, 384516, 400342, 401036, 402158, 403290, 405095, 406011, 420219, 420825, 423674, 440330, 441213, 442380, 444276, 450593, 473019, 474195, 475670, 477247, 478619, 479866, 495309, 496105, 497124, 498102, 516553, 517444, 518846, ...], 'Aadhav': [138429], 'Aadhya': [51273, 78254, 86316, 93930, 96693, 100466, 104369, 165499, 166085, 208455, 
# ...

# %%
#STEP 8: How many different names exist in the dataset

Names.count()
# Out:
# Unnamed: 0    1016395
# Id            1016395
# Name          1016395
# Year          1016395
# Gender        1016395
# State         1016395
# Count         1016395
# dtype: int64

# %%
#STEP 9: What is the name with most occurrences

b= baby_names.groupby('Name')
b= b.sum()
b= b.sort_values(['Name'], ascending=False)
b.head(1)
# Out:
#         Unnamed: 0        Id   Year  Count
# Name
# Zyriah    34146196  34146205  18087     58

# %%
#STEP 10: How many different names have the least occurrences

b= baby_names.groupby('Name')
b= b.sum()
b= b.sort_values(['Name'], ascending=True)
b.head(1)
# Out:
#        Unnamed: 0       Id  Year  Count
# Name
# Aaban     7733801  7733803  4027     12

# %%
#STEP 11: What is the median name occurrence

b.median()
# Out:
# Unnamed: 0    19634616.5
# Id            19634625.5
# Year             16061.0
# Count               49.0
# dtype: float64

# %%
#STEP 12: What is the standard deviation of names
baby_names["Name"].std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      72                 with np.errstate(invalid="ignore"):
# ---> 73                     return f(*args, **kwargs)
#      74             except ValueError as e:
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     134             else:
# --> 135                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     136
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in nanvar(values, axis, skipna, ddof, mask)
#     888     # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# --> 889     avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#     890     if axis is not None:
#
# ...

# %%
#STEP 13: Get a summary with the mean, min, max, std and quartiles
